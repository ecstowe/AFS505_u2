# %% [markdown]
# # Lesson 7 Practice: Matplotlib
#
# Use this notebook to follow along with the lesson in the corresponding lesson notebook: [L07-Matplotlib-Lesson.ipynb](./L07-Matplotlib-Lesson.ipynb).

# %% [markdown]
# ## Instructions
# Follow along with the teaching material in the lesson. Throughout the tutorial sections labeled as "Tasks" are interspersed and indicated with the icon: ![Task](http://icons.iconarchive.com/icons/sbstnblnd/plateau/16/Apps-gnome-info-icon.png). You should follow the instructions provided in these sections by performing them in the practice notebook.  When the tutorial is completed you can turn in the final practice notebook. For each task, use the cell below it to write and test your code.  You may add additional cells for any task as needed or desired.

# %% [markdown]
# ## Task 1a: Setup
#
# Import the following packages:
# + `pandas` as `pd`
# + `numpy` as `np`
# + `matplotlib.pyplot` as `plt`
#
# Activate the `%matplotlib inline` magic.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 1b: Load Data
#
# Load the Iris data (same as in the Pandas tasks).

# %%
df = pd.read_csv('./iris.csv')

# %% [markdown]
# ## Task 2a: Create a figure
#
# Create the a scatter plot using the iris data, but compare `petal_width` to `petal_length`.  Be sure to add labels to the axes.

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(df['petal_width'].values, df['petal_length'].values)

ax.axes.set_xlabel('Petal Width (cm)')
ax.axes.set_ylabel('Petal Length (cm)')

fig.suptitle('Petal Length vs. Petal Width')
plt.show()

# %% [markdown]
# ## Task 3a: Figure Style
#
# Create a scatter plots using the iris data frame. Do not convert the data frame columns to numpy arrays. Rather use the dataframe as is. Be sure to:
# - plot `petal_length` vs `petal_width`.
# - Use column names to specify the x and y coordinates (don't pass in Numpy arrays)
# - Color each dot by the species (you'll need to be creative to do this).
#   - Hint 1: use the [pd.Series.replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) function to convert species names to colors).
#   - Hint 2: Use the color abbreviations we learned for the the plot function (e.g. 'r', 'b', 'g', etc.).
# - Add axis labels

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2      go
# 1           4.9          3.0           1.4          0.2      go
# 2           4.7          3.2           1.3          0.2      go
# 3           4.6          3.1           1.5          0.2      go
# 4           5.0          3.6           1.4          0.2      go

# %%
df.replace('setosa','g', inplace = True)
df.replace('virginica','r', inplace = True)
df.replace('versicolor', 'b', inplace = True)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

colors = df.iloc[:,5:].values()

ax.scatter(df['petal_width'], df['petal_length'], color = colors)

ax.axes.set_xlabel('Petal Width')
ax.axes.set_ylabel('Petal Length')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-fcb581f2f3b1> in <module>
#       6 ax = fig.add_subplot(1, 1, 1)
#       7
# ----> 8 colors = df.iloc[:,5:].values()
#       9
#      10 ax.scatter(df['petal_width'], df['petal_length'], color = colors)
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# ## Task 4a: Categorical plots
#
# Create a bar graph that indicates the mean `sepal_length` of each subspecies.

# %%
species_sepal = df.groupby(['sepal_length', 'species'])
species_sepal.mean()
# Out:
#                       sepal_width  petal_length  petal_width
# sepal_length species
# 4.3          go          3.000000      1.100000     0.100000
# 4.4          go          3.033333      1.333333     0.200000
# 4.5          go          2.300000      1.300000     0.300000
# 4.6          go          3.325000      1.325000     0.225000
# 4.7          go          3.200000      1.450000     0.200000
# 4.8          go          3.180000      1.580000     0.200000
# 4.9          bo          2.400000      3.300000     1.000000
#              go          3.075000      1.475000     0.125000
#              ro          2.500000      4.500000     1.700000
# 5.0          bo          2.150000      3.400000     1.000000
#              go          3.362500      1.450000     0.287500
# 5.1          bo          2.500000      3.000000     1.100000
#              go          3.600000      1.562500     0.312500
# 5.2          bo          2.700000      3.900000     1.400000
#              go          3.666667      1.466667     0.166667
# 5.3          go          3.700000      1.500000     0.200000
# 5.4          bo          3.000000      4.500000     1.500000
#              go          3.660000      1.540000     0.320000
# 5.5          bo          2.440000      3.980000     1.180000
#              go          3.850000      1.350000     0.200000
# 5.6          bo          2.820000      4.060000     1.300000
#              ro          2.800000      4.900000     2.000000
# 5.7          bo          2.820000      4.100000     1.220000
#              go          4.100000      1.600000     0.350000
#              ro          2.500000      5.000000     2.000000
# 5.8          bo          2.666667      4.000000     1.133333
#              go          4.000000      1.200000     0.200000
#              ro          2.733333      5.100000     2.066667
# 5.9          bo          3.100000      4.500000     1.650000
#              ro          3.000000      5.100000     1.800000
# 6.0          bo          2.800000      4.525000     1.425000
#              ro          2.600000      4.900000     1.650000
# 6.1          bo          2.875000      4.500000     1.325000
#              ro          2.800000      5.250000     1.600000
# 6.2          bo          2.550000      4.400000     1.400000
#              ro          3.100000      5.100000     2.050000
# 6.3          bo          2.700000      4.666667     1.466667
#              ro          2.933333      5.366667     1.983333
# 6.4          bo          3.050000      4.400000     1.400000
#              ro          2.920000      5.460000     2.060000
# 6.5          bo          2.800000      4.600000     1.500000
#              ro          3.050000      5.400000     2.000000
# 6.6          bo          2.950000      4.500000     1.350000
# 6.7          bo          3.066667      4.700000     1.533333
#              ro          3.040000      5.600000     2.220000
# 6.8          bo          2.800000      4.800000     1.400000
#              ro          3.100000      5.700000     2.200000
# 6.9          bo          3.100000      4.900000     1.500000
#              ro          3.133333      5.400000     2.233333
# 7.0          bo          3.200000      4.700000     1.400000
# 7.1          ro          3.000000      5.900000     2.100000
# 7.2          ro          3.266667      5.966667     1.966667
# 7.3          ro          2.900000      6.300000     1.800000
# 7.4          ro          2.800000      6.100000     1.900000
# 7.6          ro          3.000000      6.600000     2.100000
# 7.7          ro          3.050000      6.600000     2.200000
# 7.9          ro          3.800000      6.400000     2.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar(
plt.show()

# %% [markdown]
# ## Task 6a:  Multiple Plots
#
# Create 4 scatterplots for the iris data all in one figure. The figure should include scatterplots of these comparisions:
# - `sepal_length` x `petal_length`
# - `sepal_length` x `petal_width`
# - `sepal_width` x `petal_length`
# - `sepal_width` x `petal_width`
#
# Be sure that:
# - the points for the species
# - the axes for each plot are labeled
# - the figure has a label.

# %%
fig = plt.figure(figsize=(15, 5))

ax1 = fig.add_subplot(1, 4, 1)
ax2 = fig.add_subplot(1, 4, 2)
ax3 = fig.add_subplot(1, 4, 3)
ax4 = fig.add_subplot(1, 4, 4)

ax1.plot(df['sepal_length'], df['petal_length'], 'ro')
ax1.axes.set_xlabel('Sepal Length')
ax1.axes.set_ylabel('Petal Length')
ax2.plot(df['sepal_length'], df['petal_width'], 'go')
ax2.axes.set_xlabel('Sepal Length')
ax2.axes.set_ylabel('Petal Width')
ax3.plot(df['sepal_width'], df['petal_length'], 'bo')
ax3.axes.set_xlabel('Sepal Width')
ax3.axes.set_ylabel('Petal Length')
ax4.plot(df['sepal_width'], df['petal_width'], 'mo')
ax4.axes.set_xlabel('Sepal Width')
ax4.axes.set_ylabel('Petal Width')
fig.suptitle('Comparison Scatterplots')

plt.show()
